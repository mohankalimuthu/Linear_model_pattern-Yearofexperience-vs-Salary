# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Salary_dataset.csv')

# %%
df
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# 21          21              7.2   98274.0
# 22          22              8.0  101303.0
# 23          23              8.3  113813.0
# 24          24              8.8  109432.0
# 25          25              9.1  105583.0
# 26          26              9.6  116970.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0
# 29          29             10.6  121873.0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'YearsExperience', 'Salary'], dtype='object')

# %%
plt.scatter(df['YearsExperience'],df['Salary'])
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x = df[['YearsExperience']]
y = df['Salary']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.9537261126796983

# %%
model.score(x_test,y_test)
# Out:
# 0.9642584913814131

# %%
import numpy as np

# %%
y_pred = model.predict(x)
print(y_pred)
# Out:
# [ 36484.56411474  38338.25089098  40191.93766723  44826.15460785
#   46679.84138409  53167.74510096  54094.58848908  55948.27526533
#   55948.27526533  60582.49220594  62436.17898219  63363.02237031
#   63363.02237031  64289.86575844  67997.23931093  71704.61286342
#   73558.29963967  75411.98641591  80973.04674465  81899.89013278
#   89314.63723776  92095.16740213  99509.91450712 102290.44467149
#  106924.66161211 109705.19177648 114339.40871709 115266.25210522
#  121754.15582208 123607.84259833]

# %%
plt.scatter(x,y_pred)
plt.show()

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
x1 = 1.2
x2 = 1.4
y1 = 39344
y2 = 46206

# %%
m = (y2-y1)//(x2-x1)
m
# Out:
# 34310.0

# %%
print(y2-y1)
print(x2-x1)
# Out:
# -8474
# 0.20000000000000018

# %%
m = -8474//0.2000000000000018

# %%
m
# Out:
# -42370.0
